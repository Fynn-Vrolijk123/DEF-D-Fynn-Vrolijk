# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 27    |  |
# | :-------------|:-------------|
# | Fynn Vrolijk| 6445926 |
# | Annelinde Tijdhof| 6327508 |
# | Matthijs Oostrum| 6540546|

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: XX     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 10:45-12:00 | Annelinde |
# | ontwerp-eis berekenen| 10:45-12:00| Matthijs en Fynn|
# | Schetsen | 11:00-12:30| hele groep |
# | Bouwen | 13:45-16:00 | hele groep |
# | Werkende testopstelling | 12:30 | ---|
# | Klaar | 16:45| ---|
# | Pauze 1| 12:30-13:45 | hele groep |
# | Pauze 2| 16:00-16:15| hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 4 |
# | hoe lang voor één meting | 3sec |
# | verwacht nauwkeurigheid meting | 93% |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
#f0 moet kleiner zijn dan 2.5 Hz
C = 246
m = 1
kf = np.sqrt(C/m)/(2*np.pi)
print(f'De maximale kantelfrequentie is {kf:.2g} Hz')
# Out:
# De maximale kantelfrequentie is 2.5 Hz

# %%
f = np.linspace(0,20,100)
Ver = np.abs(1/(1-f**2/kf**2))
plt.plot(f,Ver, label = 'Verhouding')
plt.xlabel('Frequentie ($Hz$)')
plt.ylabel('Verhouding')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %%
g = 9.81
dx = g/(kf*2*np.pi)**2
print(f'De minimale delta-x is {dx:.3f} m')
# Out:
# De minimale delta-x is 0.040 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
m = np.linspace(0,5,100)
C1 = np.linspace(0,5/dx,100)
C2 = C1*0.5
C3 = C1*0.2
plt.plot(m,C1, label =  'dx = 0.0399')
plt.plot(m,C2, label =  'dx*2 = 0.0798')
plt.plot(m,C3, label = 'dx*5 = 0.1993')
plt.xlabel('massa($kg$)')
plt.ylabel('Veerconstante')
plt.legend()
plt.show()
plt.savefig('GrafiekDEFD5', dpi =800)

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - Massa verhogen
# - Lagere veerconstante --> plank verder naar buiten schuiven
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Gebruikte waarden:
#
# Verwachte oppervlakte = 0.548cm^2
#
# Veerconstante = 246 N/m
#
# E = (246*1)/0.0000548 = 4.5 MPa
#
# Er volgt L = 4.5Mpa * 0.548cm^2 * 1/246 = 1.06m
#
# Als groep gaan we mikken op een $\Delta x$ van: 4.2cm

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Schets.png" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 18cm
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Ja
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# 25cm
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Het is ruim boven 4.2cm en heeft zo'n 7 cm extra ruimte
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
kfn = 7.382/(2*np.pi)
Vern = np.abs(1/(1-(f**2/kfn**2)))
plt.plot(f,Ver, label = 'Verhouding')
plt.plot(f,Vern, label = 'Verhouding meetopstelling')
plt.xlabel('Frequentie ($Hz$)')
plt.ylabel('Verhouding')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
Freq = np.array([2,3,5])
Am = np.array([0.19,1.01,0.83])
Av = np.array([0.62,5.70,6.06])
Verhfinal = Am/Av
plt.plot(Freq,Verhfinal, '.', label = 'meetdata')
plt.plot(f,Ver, label = 'Verhouding geschat')
plt.plot(f,Vern, label = 'Verhouding meetopstelling')
plt.title('Verhouding amplitude vloer t.o.v. meting per frequentie')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Verhouding')
plt.xlabel('Frequentie($Hz$)')
plt.errorbar(Freq,Verhfinal,xerr=0.1, yerr=0.06, fmt = '.')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# #### Inzien dat parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte spannen.

# %% [markdown]
# Gekozen waarden voor minimale ontwerpeis, f < 2.5Hz(afleiding foto hieronder):
#
# Verwachte oppervlakte = 0.548cm^2
#
# Veerconstante = 246 N/m
#
# $\Delta x$ = 4.0cm
#
# Gebruikte waarden:
#
# E = (246*1)/0.0000548 = 4.5 MPa
#
# Er volgt L = 4.5Mpa * 0.548cm^2 * 1/246 = 1.06m
#
# Als groep gaan we mikken op een $\Delta x$ van: 4.2cm om onnauwkeurigheden op te vangen

# %% [markdown]
# <img src="Afleiding.jpg" width="400">
# <img src="Afleidingf.jpg" width="400">

# %% [markdown]
# #### Kunnen werken met ontwerpparameters, die een ontwerpruimte opspannen

# %%
#f0 moet kleiner zijn dan 2.5 Hz. 
C = 246
m = 1
kf = np.sqrt(C/m)/(2*np.pi)
print(f'De maximale kantelfrequentie is {kf:.2g} Hz')

f = np.linspace(0,20,100)
Ver = np.abs(1/(1-f**2/kf**2))
plt.plot(f,Ver, label = 'Verhouding')
plt.xlabel('Frequentie ($Hz$)')
plt.ylabel('Verhouding')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

g = 9.81
dx = g/(kf*2*np.pi)**2
print(f'De minimale delta-x is {dx:.3f} m')
# Out:
# De maximale kantelfrequentie is 2.5 Hz
# De minimale delta-x is 0.040 m

# %% [markdown]
# <img src="Opstelling.jpeg" width="400">

# %%
Freq = np.array([2,3,5])
Am = np.array([0.19,1.01,0.83])
Av = np.array([0.62,5.70,6.06])
Verhfinal = Am/Av
plt.plot(Freq,Verhfinal, '.', label = 'meetdata')
plt.plot(f,Ver, label = 'Verhouding geschat')
plt.plot(f,Vern, label = 'Verhouding meetopstelling')
plt.title('Verhouding amplitude vloer t.o.v. meting per frequentie')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Verhouding')
plt.xlabel('Frequentie($Hz$)')
plt.errorbar(Freq,Verhfinal,xerr=0.1, yerr=0.06, fmt = '.')
plt.legend()
plt.show()

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# ![image.png](attachment:image.png)
# <img src="Schets.png" width="400">
# <img src="Opstelling.jpeg" width="400">
